# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("C:/Users/gande/OneDrive/Desktop/A/project/AB--dashboard/Merged_dataset.csv")
print(dataset)
# Out:
#        Campaign Name                 Date  Spend [USD]  # of Impressions  \
# 0   Control Campaign  2019-08-01 00:00:00         2280             82702
# 1   Control Campaign  2019-08-02 00:00:00         1757            121040
# 2   Control Campaign  2019-08-03 00:00:00         2343            131711
# 3   Control Campaign  2019-08-04 00:00:00         1940             72878
# 4   Control Campaign  2019-08-06 00:00:00         3083            109076
# 5   Control Campaign  2019-08-07 00:00:00         2544            142123
# 6   Control Campaign  2019-08-08 00:00:00         1900             90939
# 7   Control Campaign  2019-08-09 00:00:00         2813            121332
# 8   Control Campaign  2019-08-10 00:00:00         2149            117624
# 9   Control Campaign  2019-08-11 00:00:00         2490            115247
# 10  Control Campaign  2019-08-12 00:00:00         2319            116639
# 11  Control Campaign  2019-08-13 00:00:00         2697             82847
# ...

# %%
dataset.shape
# Out:
# (59, 10)

# %%
dataset.isnull().sum()
# Out:
# Campaign Name          0
# Date                   0
# Spend [USD]            0
# # of Impressions       0
# Reach                  0
# # of Website Clicks    0
# # of Searches          0
# # of View Content      0
# # of Add to Cart       0
# # of Purchase          0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Campaign Name        59 non-null     object
#  1   Date                 59 non-null     object
#  2   Spend [USD]          59 non-null     int64
#  3   # of Impressions     59 non-null     int64
#  4   Reach                59 non-null     int64
#  5   # of Website Clicks  59 non-null     int64
#  6   # of Searches        59 non-null     int64
#  7   # of View Content    59 non-null     int64
#  8   # of Add to Cart     59 non-null     int64
#  9   # of Purchase        59 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 4.7+ KB

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'], errors='coerce')

# %%
dataset.select_dtypes(include="object").columns
# Out:
# Index(['Campaign Name'], dtype='object')

# %%
dataset.describe().T
# Out:
#                     count                           mean                  min  \
# Date                   59  2019-08-15 16:16:16.271186432  2019-08-01 00:00:00
# Spend [USD]          59.0                    2435.762712               1757.0
# # of Impressions     59.0                   91775.881356              22521.0
# Reach                59.0                   70868.644068              10598.0
# # of Website Clicks  59.0                     5682.59322               2277.0
# # of Searches        59.0                    2321.813559               1001.0
# # of View Content    59.0                    1900.169492                848.0
# # of Add to Cart     59.0                    1087.220339                278.0
# # of Purchase        59.0                          522.0                222.0
#
#                                      25%                  50%  \
# Date                 2019-08-08 12:00:00  2019-08-16 00:00:00
# Spend [USD]                       2113.5               2421.0
# ...

# %%
dataset.describe(include="object")
# Out:
#         Campaign Name
# count              59
# unique              2
# top     Test Campaign
# freq               30

# %%
int_columns = dataset.select_dtypes(include=['int64'])

sum_of_int_columns = int_columns.sum()

print(sum_of_int_columns)
# Out:
# Spend [USD]             143710
# # of Impressions       5414777
# Reach                  4181250
# # of Website Clicks     335273
# # of Searches           136987
# # of View Content       112110
# # of Add to Cart         64146
# # of Purchase            30798
# dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")
for i in dataset.select_dtypes(include="number").columns:
    sns.histplot(data=dataset,x=i)
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")
for i in dataset.select_dtypes(include="number").columns:
    plt.figure(figsize=(15,6))
    sns.kdeplot(data=dataset,x=i)
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")
for i in dataset.select_dtypes(include="number").columns:
    sns.boxplot(data=dataset,x=i)
    plt.show()
